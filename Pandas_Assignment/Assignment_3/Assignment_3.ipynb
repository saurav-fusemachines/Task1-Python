# %%
import pandas as pd
import numpy as np

# %%
countries_df=pd.read_csv("countries.csv")
countries_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                          0.50        1803.987
# 1                          2.89       11803.431
# 2                          1.90       13913.839
# 3                           NaN             NaN
# ...

# %% [markdown]
# ### Q.1 How many countries does the dataframe contain?

# %%
countries_df.location.count()
# Out:
# 210

# %% [markdown]
# ### Q.2 Retrieve a list of continents from the dataframe?

# %%
continent_list=countries_df['continent'].unique()
print(continent_list)
# Out:
# ['Asia' 'Europe' 'Africa' 'North America' 'South America' 'Oceania']

# %% [markdown]
# ### Q.3 What is the total population of all the countries in this dataset?

# %%
total_population=countries_df['population'].sum()
print("The total population of all countries is:",total_population)
# Out:
# The total population of all countries is: 7757980095.0

# %% [markdown]
# ### Q.4 What is the overall life expectancy across the world?

# %%
countries_df['life_expectancy'].mean()
# Out:
# 73.52985507246377

# %% [markdown]
# ### Q.5 Create a dataframe containing 10 countries with the highest population.

# %%
highest_population=countries_df.sort_values('population',ascending=False)
highest_population.head(10)
# Out:
#           location      continent    population  life_expectancy  \
# 41           China           Asia  1.439324e+09            76.91
# 90           India           Asia  1.380004e+09            69.66
# 199  United States  North America  3.310026e+08            78.86
# 91       Indonesia           Asia  2.735236e+08            71.72
# 145       Pakistan           Asia  2.208923e+08            67.27
# 27          Brazil  South America  2.125594e+08            75.88
# 141        Nigeria         Africa  2.061396e+08            54.69
# 15      Bangladesh           Asia  1.646894e+08            72.59
# 157         Russia         Europe  1.459345e+08            72.58
# 125         Mexico  North America  1.289328e+08            75.05
#
#      hospital_beds_per_thousand  gdp_per_capita
# 41                         4.34       15308.712
# 90                         0.53        6426.674
# 199                        2.77       54225.446
# 91                         1.04       11188.744
# ...

# %% [markdown]
# ### Q.6 Add a new column in countries_df to record the overall GDP per country (product of population & per capita GDP)

# %%
countries_df['GDP'] =  countries_df['population']*countries_df['gdp_per_capita']
print(countries_df['GDP'])
# Out:
# 0      7.022622e+10
# 1      3.396791e+10
# 2      6.101364e+11
# 3               NaN
# 4      1.912651e+11
#            ...
# 205    6.007624e+11
# 206             NaN
# 207    4.411699e+10
# 208    6.782303e+10
# 209    2.823622e+10
# Name: GDP, Length: 210, dtype: float64

# %% [markdown]
# ### Q.7 Create a dataframe containing 10 countries with the lowest GDP per capita, among the counties with population greater than 100 million.

# %%
lowest_gdp = countries_df[countries_df.population>100e6].sort_values('gdp_per_capita').head(10)
lowest_gdp
# Out:
#         location      continent    population  life_expectancy  \
# 63      Ethiopia         Africa  1.149636e+08            66.60
# 15    Bangladesh           Asia  1.646894e+08            72.59
# 145     Pakistan           Asia  2.208923e+08            67.27
# 141      Nigeria         Africa  2.061396e+08            54.69
# 90         India           Asia  1.380004e+09            69.66
# 151  Philippines           Asia  1.095811e+08            71.23
# 58         Egypt         Africa  1.023344e+08            71.99
# 91     Indonesia           Asia  2.735236e+08            71.72
# 27        Brazil  South America  2.125594e+08            75.88
# 41         China           Asia  1.439324e+09            76.91
#
#      hospital_beds_per_thousand  gdp_per_capita           GDP
# 63                         0.30        1729.927  1.988786e+11
# 15                         0.80        3523.984  5.803628e+11
# 145                        0.60        5034.708  1.112128e+12
# ...

# %% [markdown]
# ### Q.8 Create a data frame that counts the number of countries in each continent?

# %%
N_country = countries_df.groupby('continent').count()
N_country['location']
# Out:
# continent
# Africa           55
# Asia             47
# Europe           51
# North America    36
# Oceania           8
# South America    13
# Name: location, dtype: int64

# %% [markdown]
# ### Q.9 Create a data frame showing the total population of each continent.

# %%
continent_pop_df = countries_df.groupby('continent').population.sum()
continent_pop_df
# Out:
# continent
# Africa           1.339424e+09
# Asia             4.607388e+09
# Europe           7.485062e+08
# North America    5.912425e+08
# Oceania          4.095832e+07
# South America    4.304611e+08
# Name: population, dtype: float64

# %%
covid_data_set_url='https://hub.jovian.ml/wp-content/uploads/2020/09/covid-countries-data.csv'
covid_df = pd.read_csv("covid-countries-data.csv")
covid_df.head()
# Out:
#       location  total_cases  total_deaths  total_tests
# 0  Afghanistan      38243.0        1409.0          NaN
# 1      Albania       9728.0         296.0          NaN
# 2      Algeria      45158.0        1525.0          NaN
# 3      Andorra       1199.0          53.0          NaN
# 4       Angola       2729.0         109.0          NaN

# %% [markdown]
# ### Q.10 Count the number of countries for which the total_tests data is missing.

# %%
total_tests_missing = covid_df.total_tests.isna().count()
total_tests_missing
# Out:
# 212

# %% [markdown]
# ### Q.11 Merge countries_df with covid_data_df on the location column as combined_df

# %%
combined_df = countries_df.merge(covid_df,on='location')
combined_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita  total_cases  total_deaths  \
# 0                          0.50        1803.987      38243.0        1409.0
# 1                          2.89       11803.431       9728.0         296.0
# ...

# %% [markdown]
# ### Q.12 Add columns tests_per_million, cases_per_million and deaths_per_million into combined_df.

# %%
combined_df['tests_per_million']= combined_df['total_tests']*1e6 / combined_df['population']
combined_df['cases_per_million'] = combined_df['total_cases']*1e6 / combined_df['population']
combined_df['deaths_per_million'] = combined_df['total_deaths']*1e6 / combined_df['population']

combined_df.head()
# Out:
#       location continent  population  life_expectancy  \
# 0  Afghanistan      Asia  38928341.0            64.83
# 1      Albania    Europe   2877800.0            78.57
# 2      Algeria    Africa  43851043.0            76.88
# 3      Andorra    Europe     77265.0            83.73
# 4       Angola    Africa  32866268.0            61.15
#
#    hospital_beds_per_thousand  gdp_per_capita  total_cases  total_deaths  \
# 0                        0.50        1803.987      38243.0        1409.0
# 1                        2.89       11803.431       9728.0         296.0
# 2                        1.90       13913.839      45158.0        1525.0
# 3                         NaN             NaN       1199.0          53.0
# 4                         NaN        5819.495       2729.0         109.0
#
#    total_tests  tests_per_million  cases_per_million  deaths_per_million
# 0          NaN                NaN         982.394806           36.194710
# ...

# %% [markdown]
# ### Q.13 Create a dataframe with 10 countries that have the highest number of tests per million people.

# %%
highest_tests = combined_df.sort_values('tests_per_million',ascending=False).head(10)
highest_tests
# Out:
#                  location      continent   population  life_expectancy  \
# 197  United Arab Emirates           Asia    9890400.0            77.97
# 14                Bahrain           Asia    1701583.0            77.29
# 115            Luxembourg         Europe     625976.0            82.25
# 122                 Malta         Europe     441539.0            82.53
# 53                Denmark         Europe    5792203.0            80.90
# 96                 Israel           Asia    8655541.0            82.97
# 89                Iceland         Europe     341250.0            82.99
# 157                Russia         Europe  145934460.0            72.58
# 199         United States  North America  331002647.0            78.86
# 10              Australia        Oceania   25499881.0            83.44
#
#      hospital_beds_per_thousand  gdp_per_capita  total_cases  total_deaths  \
# 197                       1.200       67293.483      71540.0         387.0
# ...

# %% [markdown]
# ### Q.14 Create a dataframe with 10 countries that have the highest number of positive cases per million people.

# %%
highes_cases = combined_df.sort_values('cases_per_million',ascending=False).head(10)
highes_cases
# Out:
#           location      continent   population  life_expectancy  \
# 155          Qatar           Asia    2881060.0            80.23
# 14         Bahrain           Asia    1701583.0            77.29
# 147         Panama  North America    4314768.0            78.51
# 40           Chile  South America   19116209.0            80.18
# 162     San Marino         Europe      33938.0            84.97
# 9            Aruba  North America     106766.0            76.29
# 105         Kuwait           Asia    4270563.0            75.49
# 150           Peru  South America   32971846.0            76.74
# 27          Brazil  South America  212559409.0            75.88
# 199  United States  North America  331002647.0            78.86
#
#      hospital_beds_per_thousand  gdp_per_capita  total_cases  total_deaths  \
# 155                        1.20      116935.600     119206.0         199.0
# 14                         2.00       43290.705      52440.0         190.0
# ...

# %% [markdown]
# ### Q.15 Create a dataframe with 10 countries that have the highest number of deaths cases per million people?

# %%
highest_death = combined_df.sort_values('deaths_per_million',ascending=False).head(10)
highest_death
# Out:
#            location      continent   population  life_expectancy  \
# 162      San Marino         Europe      33938.0            84.97
# 150            Peru  South America   32971846.0            76.74
# 18          Belgium         Europe   11589616.0            81.63
# 3           Andorra         Europe      77265.0            83.73
# 177           Spain         Europe   46754783.0            83.56
# 198  United Kingdom         Europe   67886004.0            81.32
# 40            Chile  South America   19116209.0            80.18
# 97            Italy         Europe   60461828.0            83.51
# 27           Brazil  South America  212559409.0            75.88
# 182          Sweden         Europe   10099270.0            82.80
#
#      hospital_beds_per_thousand  gdp_per_capita  total_cases  total_deaths  \
# 162                        3.80       56861.470        735.0          42.0
# 150                        1.60       12236.706     663437.0       29259.0
# ...
